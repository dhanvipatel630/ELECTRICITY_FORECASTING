# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
import pandas as pd

data = pd.read_csv("/content/continuous dataset.csv.zip")  # Make sure the file has .csv extension

# %%
data
# Out:
#                   datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc  \
# 0      2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174
# 1      2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418
# 2      2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480
# 3      2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273
# 4      2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281
# ...                    ...         ...        ...       ...       ...
# 48043  2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511
# 48044  2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848
# 48045  2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251
# 48046  2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178
# 48047  2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965
#
#          W2M_toc    T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  \
# ...

# %%
#check some basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48048 entries, 0 to 48047
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    48048 non-null  object
#  1   nat_demand  48048 non-null  float64
#  2   T2M_toc     48048 non-null  float64
#  3   QV2M_toc    48048 non-null  float64
#  4   TQL_toc     48048 non-null  float64
#  5   W2M_toc     48048 non-null  float64
#  6   T2M_san     48048 non-null  float64
#  7   QV2M_san    48048 non-null  float64
#  8   TQL_san     48048 non-null  float64
#  9   W2M_san     48048 non-null  float64
#  10  T2M_dav     48048 non-null  float64
#  11  QV2M_dav    48048 non-null  float64
#  12  TQL_dav     48048 non-null  float64
#  13  W2M_dav     48048 non-null  float64
#  14  Holiday_ID  48048 non-null  int64
#  15  holiday     48048 non-null  int64
#  16  school      48048 non-null  int64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 6.2+ MB

# %%
#convert the column datatype to datetime format
data["datetime"] = pd.to_datetime(data["datetime"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48048 entries, 0 to 48047
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    48048 non-null  datetime64[ns]
#  1   nat_demand  48048 non-null  float64
#  2   T2M_toc     48048 non-null  float64
#  3   QV2M_toc    48048 non-null  float64
#  4   TQL_toc     48048 non-null  float64
#  5   W2M_toc     48048 non-null  float64
#  6   T2M_san     48048 non-null  float64
#  7   QV2M_san    48048 non-null  float64
#  8   TQL_san     48048 non-null  float64
#  9   W2M_san     48048 non-null  float64
#  10  T2M_dav     48048 non-null  float64
#  11  QV2M_dav    48048 non-null  float64
#  12  TQL_dav     48048 non-null  float64
#  13  W2M_dav     48048 non-null  float64
#  14  Holiday_ID  48048 non-null  int64
#  15  holiday     48048 non-null  int64
#  16  school      48048 non-null  int64
# dtypes: datetime64[ns](1), float64(13), int64(3)
# ...

# %%
# set datetime as index
data.set_index("datetime", inplace=True)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
# check statistics
data.describe()
# Out:
#          nat_demand       T2M_toc      QV2M_toc       TQL_toc       W2M_toc  \
# count  48048.000000  48048.000000  48048.000000  48048.000000  48048.000000
# mean    1182.868647     27.399111      0.018313      0.079979     13.391049
# std      192.068896      1.675462      0.001607      0.065589      7.295502
# min       85.192500     22.953455      0.012054      0.000000      0.008979
# 25%     1020.056900     26.160455      0.017236      0.026451      7.544958
# 50%     1168.427700     27.118051      0.018590      0.065201     12.182103
# 75%     1327.563950     28.558344      0.019521      0.117310     18.661282
# max     1754.882000     35.039575      0.022690      0.521240     39.229726
#
#             T2M_san      QV2M_san       TQL_san       W2M_san       T2M_dav  \
# count  48048.000000  48048.000000  48048.000000  48048.000000  48048.000000
# mean      26.921023      0.017844      0.106265      7.046675     24.719513
# ...

# %%
#check for missing values
data.isnull().sum()
# Out:
# nat_demand    0
# T2M_toc       0
# QV2M_toc      0
# TQL_toc       0
# W2M_toc       0
# T2M_san       0
# QV2M_san      0
# TQL_san       0
# W2M_san       0
# T2M_dav       0
# QV2M_dav      0
# TQL_dav       0
# W2M_dav       0
# Holiday_ID    0
# holiday       0
# school        0
# dtype: int64

# %%
#to show the records that contain any null values
data.isna().any(axis=1)
# Out:
# datetime
# 2015-01-03 01:00:00    False
# 2015-01-03 02:00:00    False
# 2015-01-03 03:00:00    False
# 2015-01-03 04:00:00    False
# 2015-01-03 05:00:00    False
#                        ...
# 2020-06-26 20:00:00    False
# 2020-06-26 21:00:00    False
# 2020-06-26 22:00:00    False
# 2020-06-26 23:00:00    False
# 2020-06-27 00:00:00    False
# Length: 48048, dtype: bool

# %%
# drops those rows that contain all mising values
data = data.dropna(how = "all")
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data[data.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [nat_demand, T2M_toc, QV2M_toc, TQL_toc, W2M_toc, T2M_san, QV2M_san, TQL_san, W2M_san, T2M_dav, QV2M_dav, TQL_dav, W2M_dav, Holiday_ID, holiday, school]
# Index: []

# %%
data.isnull().sum()
# Out:
# nat_demand    0
# T2M_toc       0
# QV2M_toc      0
# TQL_toc       0
# W2M_toc       0
# T2M_san       0
# QV2M_san      0
# TQL_san       0
# W2M_san       0
# T2M_dav       0
# QV2M_dav      0
# TQL_dav       0
# W2M_dav       0
# Holiday_ID    0
# holiday       0
# school        0
# dtype: int64

# %%
data['hour'] = data.index.hour
data['dayofweek'] = data.index.dayofweek
data['month'] = data.index.month
data['year'] = data.index.year
data['dayofyear'] = data.index.dayofyear

# %%
data[['hour','dayofweek','month','year','dayofyear']].ffill()
# Out:
#                      hour  dayofweek  month  year  dayofyear
# datetime
# 2015-01-03 01:00:00     1          5      1  2015          3
# 2015-01-03 02:00:00     2          5      1  2015          3
# 2015-01-03 03:00:00     3          5      1  2015          3
# 2015-01-03 04:00:00     4          5      1  2015          3
# 2015-01-03 05:00:00     5          5      1  2015          3
# ...                   ...        ...    ...   ...        ...
# 2020-06-26 20:00:00    20          4      6  2020        178
# 2020-06-26 21:00:00    21          4      6  2020        178
# 2020-06-26 22:00:00    22          4      6  2020        178
# 2020-06-26 23:00:00    23          4      6  2020        178
# 2020-06-27 00:00:00     0          5      6  2020        179
#
# [48048 rows x 5 columns]

# %%
data[['T2M_toc','QV2M_toc']].bfill()
# Out:
#                        T2M_toc  QV2M_toc
# datetime
# 2015-01-03 01:00:00  25.865259  0.018576
# 2015-01-03 02:00:00  25.899255  0.018653
# 2015-01-03 03:00:00  25.937280  0.018768
# 2015-01-03 04:00:00  25.957544  0.018890
# 2015-01-03 05:00:00  25.973840  0.018981
# ...                        ...       ...
# 2020-06-26 20:00:00  27.246545  0.020303
# 2020-06-26 21:00:00  27.099573  0.020395
# 2020-06-26 22:00:00  26.971155  0.020448
# 2020-06-26 23:00:00  26.867487  0.020464
# 2020-06-27 00:00:00  26.750330  0.020441
#
# [48048 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# nat_demand    0
# T2M_toc       0
# QV2M_toc      0
# TQL_toc       0
# W2M_toc       0
# T2M_san       0
# QV2M_san      0
# TQL_san       0
# W2M_san       0
# T2M_dav       0
# QV2M_dav      0
# TQL_dav       0
# W2M_dav       0
# Holiday_ID    0
# holiday       0
# school        0
# hour          0
# dayofweek     0
# month         0
# year          0
# dayofyear     0
# dtype: int64

# %%
#shape of dataframe
data.shape
# Out:
# (48048, 21)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
#create the 'Quarter' column in the dataset
data.insert(5, 'quarter', data.index.quarter)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48048 entries, 2015-01-03 01:00:00 to 2020-06-27 00:00:00
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nat_demand  48048 non-null  float64
#  1   T2M_toc     48048 non-null  float64
#  2   QV2M_toc    48048 non-null  float64
#  3   TQL_toc     48048 non-null  float64
#  4   W2M_toc     48048 non-null  float64
#  5   quarter     48048 non-null  int32
#  6   T2M_san     48048 non-null  float64
#  7   QV2M_san    48048 non-null  float64
#  8   TQL_san     48048 non-null  float64
#  9   W2M_san     48048 non-null  float64
#  10  T2M_dav     48048 non-null  float64
#  11  QV2M_dav    48048 non-null  float64
#  12  TQL_dav     48048 non-null  float64
#  13  W2M_dav     48048 non-null  float64
#  14  Holiday_ID  48048 non-null  int64
#  15  holiday     48048 non-null  int64
#  16  school      48048 non-null  int64
#  17  hour        48048 non-null  int32
# ...

# %%
data['hour'] = data.index.hour
data['dayofweek'] = data.index.dayofweek
data['month'] = data.index.month
data['year'] = data.index.year
data['dayofyear'] = data.index.dayofyear

# %%
#convert the datatype from float to intager
data[['hour','dayofweek','month','year','dayofyear']] = \
data[['hour','dayofweek','month','year','dayofyear']].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48048 entries, 2015-01-03 01:00:00 to 2020-06-27 00:00:00
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nat_demand  48048 non-null  float64
#  1   T2M_toc     48048 non-null  float64
#  2   QV2M_toc    48048 non-null  float64
#  3   TQL_toc     48048 non-null  float64
#  4   W2M_toc     48048 non-null  float64
#  5   quarter     48048 non-null  int32
#  6   T2M_san     48048 non-null  float64
#  7   QV2M_san    48048 non-null  float64
#  8   TQL_san     48048 non-null  float64
#  9   W2M_san     48048 non-null  float64
#  10  T2M_dav     48048 non-null  float64
#  11  QV2M_dav    48048 non-null  float64
#  12  TQL_dav     48048 non-null  float64
#  13  W2M_dav     48048 non-null  float64
#  14  Holiday_ID  48048 non-null  int64
#  15  holiday     48048 non-null  int64
#  16  school      48048 non-null  int64
#  17  hour        48048 non-null  int64
# ...

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
#create "week of year" column in the dataset
data.insert(5, "week_of_year", data.index.isocalendar().week.astype(int))

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data.tail(50)
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2020-06-24 23:00:00   1130.5567  27.197961  0.020844  0.028252   9.648737
# 2020-06-25 00:00:00   1102.6192  27.067834  0.020921  0.029930  10.212315
# 2020-06-25 01:00:00   1060.0075  26.959497  0.020860  0.038895  10.756265
# 2020-06-25 02:00:00   1024.9112  26.837732  0.020768  0.045273  11.257610
# 2020-06-25 03:00:00   1003.7967  26.757501  0.020646  0.044846  11.804329
# 2020-06-25 04:00:00    991.5962  26.681696  0.020478  0.042709  11.950110
# 2020-06-25 05:00:00    977.4811  26.623285  0.020318  0.042435  11.932020
# 2020-06-25 06:00:00    972.0262  26.743433  0.020310  0.043015  12.544288
# 2020-06-25 07:00:00   1072.0182  27.324152  0.020417  0.046280  15.928551
# 2020-06-25 08:00:00   1193.0333  27.817896  0.020288  0.048477  19.627917
# 2020-06-25 09:00:00   1256.3163  28.296167  0.020151  0.045502  21.273817
# ...

# %%
#create a new column to check the weekend

data['is_weekend'] = data.index.dayofweek.isin([5,6])

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data['is_weekend'] = data['is_weekend'].astype(int)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data[data['is_weekend'] == 1]
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-21 20:00:00   1298.8818  27.152460  0.020326  0.038422  11.282582
# 2020-06-21 21:00:00   1305.3179  26.919763  0.020311  0.043930  10.313275
# 2020-06-21 22:00:00   1259.3089  26.727991  0.020189  0.047852   9.383799
# 2020-06-21 23:00:00   1144.4527  26.638666  0.020067  0.054443   8.548230
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
#import holidays package

import holidays

# %%
import holidays

holidays.IN(years=data.index.year.unique())
# Out:
# {datetime.date(2016, 1, 26): 'Republic Day', datetime.date(2016, 8, 15): 'Independence Day', datetime.date(2016, 10, 2): 'Gandhi Jayanti', datetime.date(2016, 5, 21): 'Buddha Purnima', datetime.date(2016, 10, 30): 'Diwali', datetime.date(2016, 8, 25): 'Janmashtami', datetime.date(2016, 10, 11): 'Dussehra', datetime.date(2016, 4, 20): 'Mahavir Jayanti', datetime.date(2016, 3, 7): 'Maha Shivaratri', datetime.date(2016, 11, 14): 'Guru Nanak Jayanti', datetime.date(2016, 10, 12): 'Ashura', datetime.date(2016, 12, 13): "Prophet's Birthday", datetime.date(2016, 7, 7): 'Eid al-Fitr', datetime.date(2016, 9, 13): 'Eid al-Adha', datetime.date(2016, 3, 25): 'Good Friday', datetime.date(2016, 12, 25): 'Christmas', datetime.date(2017, 1, 26): 'Republic Day', datetime.date(2017, 8, 15): 'Independence Day; Janmashtami', datetime.date(2017, 10, 2): 'Gandhi Jayanti', datetime.date(2017, 5, 10): 'Buddha Purnima', datetime.date(2017, 10, 19): 'Diwali', datetime.date(2017, 9, 30): 'Dussehra', datetime.d
# ...

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
import holidays
ind_holidays = holidays.IN(years=data.index.year.unique())

# %%
data['holiday_flag'] = data.index.map(lambda x: 1 if x in ind_holidays else 0)

# %%
data['holiday_flag'].value_counts()
# Out:
# holiday_flag
# 0    46008
# 1     2040
# Name: count, dtype: int64

# %%
data = data.drop('holiday', axis=1)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
# lagged features: these are the past values of a time series data
# use - past demand values are strong predictors. they can be used as input to predict future values

# %%
#demand from the same hour yesterday, some hour last week

data['demand_lag_24hr'] = data['nat_demand'].shift(24)

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
data['demand_lag168hr'] = data['nat_demand'].shift(168) # 24*7 = 168 hours for weekly shift

# %%
data.head(50)
# Out:
#                      nat_demand    T2M_toc  QV2M_toc       TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  1.617432e-02  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  1.641846e-02  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  1.548004e-02  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  1.627350e-02  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  1.728058e-02  21.186089
# 2015-01-03 06:00:00    879.2323  26.034143  0.019080  1.454163e-02  20.062038
# 2015-01-03 07:00:00    932.4876  26.691492  0.019332  6.645203e-03  21.623496
# 2015-01-03 08:00:00   1048.9720  27.674066  0.019370  6.862640e-03  23.775317
# 2015-01-03 09:00:00   1167.9074  28.760400  0.019171  1.023102e-02  24.636152
# 2015-01-03 10:00:00   1257.5069  29.766656  0.018759  9.017944e-03  25.862671
# 2015-01-03 11:00:00   1254.5830  30.523767  0.018408  4.322052e-03  26.828082
# ...

# %%
data.iloc[160:200]
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-09 17:00:00    997.3978  27.186548  0.016839  0.024704  27.231206
# 2015-01-09 18:00:00   1054.8104  26.246484  0.017083  0.020546  24.340092
# 2015-01-09 19:00:00   1105.8630  25.844965  0.017274  0.025528  22.533117
# 2015-01-09 20:00:00   1085.7856  25.649957  0.017259  0.033508  22.215401
# 2015-01-09 21:00:00   1061.3146  25.477808  0.017228  0.023895  21.300979
# 2015-01-09 22:00:00   1033.8639  25.304468  0.017198  0.017540  20.636242
# 2015-01-09 23:00:00    989.8507  25.171594  0.017130  0.017014  20.989725
# 2015-01-10 00:00:00    949.5031  25.052789  0.017161  0.021683  20.918190
# 2015-01-10 01:00:00    906.9580  24.976495  0.017215  0.025253  21.335333
# 2015-01-10 02:00:00    863.5135  24.906274  0.017337  0.034378  22.177057
# 2015-01-10 03:00:00    848.4447  24.879724  0.017512  0.045349  22.742188
# ...

# %%
# rolling mean & rolling standard deviation
data['demand_rolling_mean_24hr'] = data['nat_demand'].rolling(window=24).mean()

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
#drop all rows having null values

data.dropna()
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-10 01:00:00    906.9580  24.976495  0.017215  0.025253  21.335333
# 2015-01-10 02:00:00    863.5135  24.906274  0.017337  0.034378  22.177057
# 2015-01-10 03:00:00    848.4447  24.879724  0.017512  0.045349  22.742188
# 2015-01-10 04:00:00    839.8821  24.907922  0.017673  0.047501  22.630025
# 2015-01-10 05:00:00    847.1073  24.932520  0.017795  0.036087  21.731658
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
# plot raw demand over time
data['nat_demand'].plot(figsize=(15,6), title="Electricity Demand Over Time")
plt.show()

# %%
# create hour column (agar pehle nahi banaya)
data['hour'] = data.index.hour

plt.figure(figsize=(10,6))
sns.boxplot(data=data, x='hour', y='nat_demand')
plt.title("Demand by Hour of the Day")
plt.show()

# %%
import seaborn as sns

# %%
# create month column (agar pehle nahi banaya)
data['month'] = data.index.month

plt.figure(figsize=(10,6))
sns.boxplot(data=data, x='month', y='nat_demand')
plt.title("Demand by Month")
plt.show()

# %%
# scatter plot of demand vs temperature
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='T2M_toc', y='nat_demand', alpha=0.5)
plt.title("Demand vs Temperature (T2M_toc)")
plt.show()

# %%
# correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, fmt=".2f")
plt.title("Correlation Matrix of Features")
plt.show()

# %%
data
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511   9.289304
# 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848   9.837504
# 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251  10.262464
# 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178  10.326567
# 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965  10.198346
#
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
from google.colab import files

files.download('cleaned_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/MyDrive/cleaned_data.csv', index=False)

# %%
Y = data['nat_demand']           #target variable / dependant variable

# %%
X = data.drop("nat_demand", axis=1)             #independant variable / features / predictors

# %%
# (print the values of target variable)
print(Y)
# Out:
# datetime
# 2015-01-03 01:00:00     970.3450
# 2015-01-03 02:00:00     912.1755
# 2015-01-03 03:00:00     900.2688
# 2015-01-03 04:00:00     889.9538
# 2015-01-03 05:00:00     893.6865
#                          ...
# 2020-06-26 20:00:00    1128.5592
# 2020-06-26 21:00:00    1112.7488
# 2020-06-26 22:00:00    1081.5680
# 2020-06-26 23:00:00    1041.6240
# 2020-06-27 00:00:00    1013.5683
# Name: nat_demand, Length: 48048, dtype: float64

# %%
X = df.drop('nat_demand', axis=1)
y = df['nat_demand']

print(X.head())
# Out:
#      T2M_toc  QV2M_toc   TQL_toc    W2M_toc    T2M_san  QV2M_san   TQL_san  \
# 0  25.865259  0.018576  0.016174  21.850546  23.482446  0.017272  0.001855
# 1  25.899255  0.018653  0.016418  22.166944  23.399255  0.017265  0.001327
# 2  25.937280  0.018768  0.015480  22.454911  23.343530  0.017211  0.001428
# 3  25.957544  0.018890  0.016273  22.110481  23.238794  0.017128  0.002599
# 4  25.973840  0.018981  0.017281  21.186089  23.075403  0.017059  0.001729
#
#      W2M_san    T2M_dav  QV2M_dav  ...  holiday  school  year  month  day  \
# 0  10.328949  22.662134  0.016562  ...        0       0  2015      1    3
# 1  10.681517  22.578943  0.016509  ...        0       0  2015      1    3
# 2  10.874924  22.531030  0.016479  ...        0       0  2015      1    3
# 3  10.518620  22.512231  0.016487  ...        0       0  2015      1    3
# 4   9.733589  22.481653  0.016456  ...        0       0  2015      1    3
#
#    hour  dayofweek     lag_1  lag_24  rolling_24
# ...

# %%
# (print the values of target variable)
print(X)
# Out:
#          T2M_toc  QV2M_toc   TQL_toc    W2M_toc    T2M_san  QV2M_san  \
# 0      25.865259  0.018576  0.016174  21.850546  23.482446  0.017272
# 1      25.899255  0.018653  0.016418  22.166944  23.399255  0.017265
# 2      25.937280  0.018768  0.015480  22.454911  23.343530  0.017211
# 3      25.957544  0.018890  0.016273  22.110481  23.238794  0.017128
# 4      25.973840  0.018981  0.017281  21.186089  23.075403  0.017059
# ...          ...       ...       ...        ...        ...       ...
# 48043  27.246545  0.020303  0.055511   9.289304  25.715295  0.019746
# 48044  27.099573  0.020395  0.053848   9.837504  25.552698  0.019632
# 48045  26.971155  0.020448  0.057251  10.262464  25.393030  0.019518
# 48046  26.867487  0.020464  0.064178  10.326567  25.258112  0.019403
# 48047  26.750330  0.020441  0.063965  10.198346  25.125330  0.019281
#
#         TQL_san    W2M_san    T2M_dav  QV2M_dav  ...  holiday  school  year  \
# ...

# %%
# splitting the data training and testing data

x_train = X.loc[: "2019-12-31"]

# %%
x_test = X.loc["2020-01-01":]

# %%
y_train = Y.loc[: "2019-12-31"]
y_test = Y.loc["2020-01-01":]

# %%
y_test
# Out:
# datetime
# 2020-01-01 00:00:00    1032.2630
# 2020-01-01 01:00:00    1017.5806
# 2020-01-01 02:00:00    1000.2797
# 2020-01-01 03:00:00     987.2383
# 2020-01-01 04:00:00     970.3667
#                          ...
# 2020-06-26 20:00:00    1128.5592
# 2020-06-26 21:00:00    1112.7488
# 2020-06-26 22:00:00    1081.5680
# 2020-06-26 23:00:00    1041.6240
# 2020-06-27 00:00:00    1013.5683
# Name: nat_demand, Length: 4273, dtype: float64

# %%
x_test
# Out:
#          T2M_toc  QV2M_toc   TQL_toc    W2M_toc    T2M_san  QV2M_san  \
# 20200  31.169489  0.016793  0.048721   3.803228  30.294489  0.017243
# 20201  30.399957  0.017281  0.036743   2.672612  28.462457  0.018388
# 20202  29.712488  0.017884  0.022163   2.601484  27.446863  0.018891
# 20203  29.144434  0.018433  0.010735   4.132525  27.003809  0.019036
# 20204  28.665186  0.018792  0.003406   6.211344  26.665186  0.019166
# ...          ...       ...       ...        ...        ...       ...
# 48043  27.246545  0.020303  0.055511   9.289304  25.715295  0.019746
# 48044  27.099573  0.020395  0.053848   9.837504  25.552698  0.019632
# 48045  26.971155  0.020448  0.057251  10.262464  25.393030  0.019518
# 48046  26.867487  0.020464  0.064178  10.326567  25.258112  0.019403
# 48047  26.750330  0.020441  0.063965  10.198346  25.125330  0.019281
#
#         TQL_san   W2M_san    T2M_dav  QV2M_dav  ...  holiday  school  year  \
# ...

# %%
x_train = X.loc[: "2019-12-31"]
y_train = Y.loc[: "2019-12-31"]

print(x_train.shape)
print(y_train.shape)
# Out:
# (20190, 23)
# (43775,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (27848, 23)
# (4273,)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit

# %%
# initialize and train the model
model_rf = RandomForestRegressor(
    n_estimators=300,      # adjusted for RF
    max_depth=15,          # helps control overfitting
    random_state=42,
    n_jobs=-1
)

# %%
X = df.drop(columns=['nat_demand'])
y = df['nat_demand']

# %%
split = int(len(df) * 0.8)

X_train = X.iloc[:split]
X_test  = X.iloc[split:]

y_train = y.iloc[:split]
y_test  = y.iloc[split:]

# %%
df['lag_1'] = df['nat_demand'].shift(1)
df['lag_24'] = df['nat_demand'].shift(24)

# %%
df['rolling_24'] = df['nat_demand'].rolling(24).mean()
df = df.dropna()

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor(
    n_estimators=100,   # reduce from 300 → 100
    max_depth=10,
    random_state=42,
    n_jobs=-1
)

# %%
top_features = [
    'hour',
    'dayofweek',
    'T2M_toc',
    'Holiday_ID',
    'holiday',
    'T2M_dav',
    'QV2M_toc',
    'month',
    'QV2M_dav',
    'TQL_toc'
]

# %%
X = X[top_features]

# %%
split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test  = X.iloc[split:]

y_train = y.iloc[:split]
y_test  = y.iloc[split:]

# %%
model_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_jobs=-1, random_state=42)

# %%
prediction_rf = model_rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, prediction_rf))
mae = mean_absolute_error(y_test, prediction_rf)

print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# RMSE: 121.20384422729403
# MAE: 95.30310638664754

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))
plt.plot(y_test.index, y_test, label="Actual")
plt.plot(y_test.index, prediction_rf, label="Predicted")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
#
plt.figure(figsize=(15,6))
plt.plot(y_test.values, label='Actual')
plt.plot(prediction_rf, label='Predicted')
plt.title("Actual vs Predicted Demand")
plt.xlabel("Time")
plt.ylabel("Demand")
plt.legend()
plt.show()

# %%
errors = y_test - prediction_rf
#Shows how wrong your model is
plt.figure(figsize=(10,5))
plt.hist(errors, bins=50)
plt.title("Error Distribution")
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
#Tells which features matter most
importance = model_rf.feature_importances_
feature_names = X.columns

feat_imp = pd.Series(importance, index=feature_names)
feat_imp = feat_imp.sort_values(ascending=False)

plt.figure(figsize=(10,6))
feat_imp.head(10).plot(kind='bar')
plt.title("Top 10 Feature Importances")
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, prediction_rf, label='Predicted')
plt.title("Time Series Prediction")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
#Helps detect patterns (model mistakes)
plt.scatter(prediction_rf, errors)
plt.axhline(y=0)
plt.title("Residual Plot")
plt.xlabel("Predicted")
plt.ylabel("Error")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()
